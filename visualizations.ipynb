# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
cotinine_levels = np.array([1, 35, 130, 123, 0, 112, 234, 167, 131, 477, 164, 250, 173, 289, 198, 245, 265, 227, 17, 48, 210, 103, 253, 86, 44, 222, 87, 284, 277, 149, 121, 1, 32, 313, 266, 208, 3, 491, 290, 173])

# %%
bins = [0, 100, 200, 300, 400, 499]

# %%
plt.hist(cotinine_levels, bins)
# Out:
# (array([11., 12., 14.,  1.,  2.]),
#  array([  0, 100, 200, 300, 400, 499]),
#  <a list of 5 Patch objects>)

# %%
plt.hist(cotinine_levels, bins, cumulative=True)
# Out:
# (array([11., 23., 37., 38., 40.]),
#  array([  0, 100, 200, 300, 400, 499]),
#  <a list of 5 Patch objects>)

# %%
plt.hist(cotinine_levels)
# Out:
# (array([9., 2., 6., 5., 7., 8., 1., 0., 0., 2.]),
#  array([  0. ,  49.1,  98.2, 147.3, 196.4, 245.5, 294.6, 343.7, 392.8,
#         441.9, 491. ]),
#  <a list of 10 Patch objects>)

# %%
clipped_cl = cotinine_levels[(cotinine_levels >= 100) & (cotinine_levels <= 300)]

# %%
plt.hist(clipped_cl, bins=5)
# Out:
# (array([6., 5., 3., 5., 7.]),
#  array([103. , 140.4, 177.8, 215.2, 252.6, 290. ]),
#  <a list of 5 Patch objects>)

# %%
complaints = {
    "Rates and Services": 4473,
    "Marketing": 1007,
    "Intl Calling": 766,
    "Access Charges": 614,
    "Operator Services": 534,
    "Slamming": 12478,
    "Cramming": 1214
}

# %%
complaints[0]
# Out:
# 'Show Godu'

# %%
tp = {
    "Rates and Services": {
        "Rates": 2273,
        "Services": 2200
    },
    "Marketing": 1007
}

# %%
tp["Rates and Services"]["Services"]
# Out:
# 2200

# %%
complaints[4473]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-ed127e4cd742> in <module>
# ----> 1 complaints[4473]
#
# KeyError: 4473

# %%
complaints.values()
# Out:
# dict_values([4473, 1007, 766, 614, 534, 12478, 1214])

# %%
plt.bar(complaints.keys(), complaints.values())
# Out:
# <BarContainer object of 7 artists>

# %%
vals = sorted(complaints.values(), reverse=True)
vals
# Out:
# [12478, 4473, 1214, 1007, 766, 614, 534]

# %%
cats = []
for val in vals:
    for k, v in complaints.items():
        if v == val:
            cats.append(k)

# %%
cats
# Out:
# ['Slamming',
#  'Rates and Services',
#  'Cramming',
#  'Marketing',
#  'Intl Calling',
#  'Access Charges',
#  'Operator Services']

# %%
plt.bar(cats, vals)
# Out:
# <BarContainer object of 7 artists>

# %%
waists = np.array([90.6,78.1,96.5,97.7,87.1,92.4,78.8,103.3,89.1,82.5,86.7,103.3,91.8,75.6,105.5,108.7,104,103,91.3,75.2,87.7,77,85,79.6,103.8,103,97.1,86.9,88,91.5,102.9,93.1,98.9,107.5,81.6,75.7,95,91.1,94.9,79.9])
waists.shape
# Out:
# (40,)

# %%
weights = np.array([169.1,144.2,179.3,175.8,152.6,166.8,135,201.5,175.2,139,156.3,186.6,191.1,151.3,209.4,237.1,176.7,220.6,166.1,137.4,164.2,162.4,151.8,144.1,204.6,193.8,172.9,161.9,174.8,169.8,213.3,198,173.3,214.5,137.1,119.5,189.1,164.7,170.1,151])
weights.shape
# Out:
# (40,)

# %%
plt.scatter(waists, weights)
